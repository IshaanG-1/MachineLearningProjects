# %%
using Plots

f(a) = a^3 - 5*a*(2-a)+6*(2-a)^2  
#the shifting is handled within the f(a) function (x1 = 0 + 1a) (x2 = 2 - 1a)
f1(a) = 24-34a
f2(a) = 24-34a+11*a^2
a = range(0, 2.5, length = 1000)
B = [f.(a), f1.(a), f2.(a)]
plot(a, B)
